# %%
#check system path

import sys
print(sys.path)
# Out:
# ['C:\\Users\\areka\\Desktop', 'C:\\Users\\areka\\anaconda3\\python37.zip', 'C:\\Users\\areka\\anaconda3\\DLLs', 'C:\\Users\\areka\\anaconda3\\lib', 'C:\\Users\\areka\\anaconda3', '', 'C:\\Users\\areka\\AppData\\Roaming\\Python\\Python37\\site-packages', 'C:\\Users\\areka\\anaconda3\\lib\\site-packages', 'C:\\Users\\areka\\anaconda3\\lib\\site-packages\\win32', 'C:\\Users\\areka\\anaconda3\\lib\\site-packages\\win32\\lib', 'C:\\Users\\areka\\anaconda3\\lib\\site-packages\\Pythonwin', 'C:\\Users\\areka\\anaconda3\\lib\\site-packages\\IPython\\extensions', 'C:\\Users\\areka\\.ipython']

# %%
#sage's system path

new_path = sys.path
res = [sub.replace('astropy-workshop', 'astroconda') for sub in new_path] 
sys.path = res
print(sys.path)

# %%
#imports :)

import glob
import os
import time
import datetime

import numpy as np

import sunpy.map

import pylab

import pandas as pd

import scipy.ndimage
from scipy.stats import norm
import matplotlib.pyplot as plt
import matplotlib.colors as colors
import matplotlib.gridspec as gridspec
import matplotlib.image as mpimg
import matplotlib.gridspec as gridspec
from matplotlib.colors import LogNorm
from matplotlib.ticker import FuncFormatter, PercentFormatter
from matplotlib import patches

from PIL import Image, ImageEnhance, ImageFont, ImageDraw
from PIL.ImageColor import getcolor, getrgb
from PIL.ImageOps import grayscale, colorize

from astropy import modeling
from astropy.io import fits

from skimage import data, color
from skimage.transform import hough_circle, hough_circle_peaks
from skimage.feature import canny
from skimage.draw import circle_perimeter
from skimage.util import img_as_ubyte
from sklearn import preprocessing

# %%
#data file path assignment

myfile = 'C:\Users\areka\Documents\Solar Sherpas\FIlter Analysis\Data'
name_0 = os.path.basename(myfile)
name = name_0.replace('.txt', '')

# %%
#create variable with data path

#df = pd.read_csv(myfile,sep='\t',skiprows=(0,18))#,header=(0))
df = pd.read_csv(myfile,sep='\t')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-20-37122f24b9f7> in <module>
#       2
#       3 #df = pd.read_csv(myfile,sep='\t',skiprows=(0,1))#,header=(0))
# ----> 4 df = pd.read_csv(myfile,sep='\t')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
#     677
#     678     parser_f.__name__ = name
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in _read(filepath_or_buffer, kwds)
#     452
#     453     try:
# --> 454         data = parser.read(nrows)
#     455     finally:
#     456         parser.close()
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    1131     def read(self, nrows=None):
#    1132         nrows = _validate_integer("nrows", nrows)
# -> 1133         ret = self._engine.read(nrows)
#    1134
#    1135         # May alter columns / col_dict
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in read(self, nrows)
#    2035     def read(self, nrows=None):
#    2036         try:
# -> 2037             data = self._reader.read(nrows)
#    2038         except StopIteration:
#    2039             if self._first_chunk:
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader.read()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_low_memory()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._read_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.TextReader._tokenize_rows()
#
# pandas\_libs\parsers.pyx in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 18, saw 2

# %%
#save data file to array_0

array_0 = pd.DataFrame.to_numpy(df)
data_x = array_0[:,0]
data_y = array_0[:,1]

# %%
#cut down the data for some reason
wl_lim = array_0[590: 647]

#find the min,mid,max for why?
high = np.where(array_0 == np.amax(wl_lim))
mid = np.rint(low)+(np.rint(high) - np.rint(low))/2
low = np.where(array_0 == np.amin(wl_lim))
print(np.rint(high))
print(mid)
print(np.rint(low))

#plot the spectra
plt.figure(figsize = (10, 10))
plt.title(f'{name}')
#plt.vlines(high, 200, 0, linestyle = 'dotted')
#plt.vlines(low, 200, 0, linestyle = 'dotted')
plt.grid(True)
plt.xlabel('Wavelength [nm]')
plt.ylabel(r'Transmission [%]')
plt.xlim(300, 1100)
plt.ylim(0, 110)
plt.plot(data_x, data_y, 'k-')
# Out:
# [[646.]
#  [  0.]]
# [[635.]
#  [  1.]]
# [[6.405e+02]
#  [5.000e-01]]

# %% [markdown]
# Let's automate this

# %%
#printing plots

data_dir = '/media/sage/D846-28C6/Optics_test_2019/data/filter*.txt'
spec_dir = '/media/sage/D846-28C6/Optics_test_2019/spectra'

tot = len(sorted(glob.glob(data_dir)))
plt.figure(figsize = (10, 10))
for index, file in enumerate(sorted(glob.glob(data_dir))):
    name_0 = os.path.basename(file)
    name = name_0.replace('.txt', '')
    df = pd.read_csv(file,sep='\t')
    array_0 = pd.DataFrame.to_numpy(df)
    
    data_x = array_0[:,0]
    data_y = array_0[:,1]
    
    
    plt.title(f'{name}')
    plt.grid(True)
    plt.xlabel('Wavelength [nm]')
    plt.ylabel(r'Transmission [%]')
    plt.xlim(300, 1100)
    plt.ylim(0, 110)
    plt.plot(data_x, data_y, 'k-', label = 'f'{name}')
    plt.savefig(f'{spec_dir}/{name}.png')
    plt.clf()
    print(f'Saving: {index + 1} of {tot} ')
# Out:
# Saving: 1 of 4
# Saving: 2 of 4
# Saving: 3 of 4
# Saving: 4 of 4

# %%
#plotting

data_dir = '/media/sage/D846-28C6/Optics_test_2019/data/filter*.txt'
spec_dir = '/media/sage/D846-28C6/Optics_test_2019/spectra'

tot = len(sorted(glob.glob(data_dir)))
plt.figure(figsize = (10, 10))
for index, file in enumerate(sorted(glob.glob(data_dir))):
    name_0 = os.path.basename(file)
    name = name_0.replace('.txt', '')
    df = pd.read_csv(file,sep='\t')
    array_0 = pd.DataFrame.to_numpy(df)
    
    data_x = array_0[:,0]
    data_y = array_0[:,1]
    
    
    plt.title('Filter Test')
    plt.grid(True)
    plt.xlabel('Wavelength [nm]')
    plt.ylabel(r'Transmission [%]')
    plt.xlim(300, 1100)
    plt.ylim(0, 110)
    plt.plot(data_x, data_y, '-', label = f'{name}')
pylab.legend(loc ='upper left', prop={'size': 12})
plt.show()
